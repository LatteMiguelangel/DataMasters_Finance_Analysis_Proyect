# %%
import pandas as pd
import cufflinks as cf
from IPython.display import display, HTML
cf.set_config_file(sharing='public', theme='space', offline=True)
#cf.getThemes() -> obtener temas
pd.read_csv('AAPL.csv', delimiter=',')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df_apple = pd.read_csv('AAPL.csv', delimiter=',')
df_apple = df_apple.dropna()

df_apple['Year'] = pd.DatetimeIndex(df_apple['Date']).year
df_apple = df_apple[['Date', 'Year', 'Volume']]
df_apple.insert(0, 'Year', df_apple.pop('Year'))
#df_apple.pivot(index=, columns=, values=)
df_apple.head(10)
# Out:
#    Year        Date     Volume
# 0  1980  1980-12-12  469033600
# 1  1980  1980-12-15  175884800
# 2  1980  1980-12-16  105728000
# 3  1980  1980-12-17   86441600
# 4  1980  1980-12-18   73449600
# 5  1980  1980-12-19   48630400
# 6  1980  1980-12-22   37363200
# 7  1980  1980-12-23   46950400
# 8  1980  1980-12-24   48003200
# 9  1980  1980-12-26   55574400
